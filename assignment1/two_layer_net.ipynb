    model = TwoLayerNet(input_size, h, num_classes, reg=reg)
    solver = Solver(model, data, optim_config={'learning_rate': lr}, batch_size=b, num_epochs=epoch, verbose=False)
    solver.train()
    train_acc, val_acc = np.max(solver.train_acc_history), solver.best_val_acc
    
    if len(top10) < 10:
        heapq.heappush(top10, (val_acc, train_acc, lr, h, b, epoch, reg))
    elif val_acc > top10[0][0]:
        heapq.heapreplace(top10, (val_acc, train_acc, lr, h, b, epoch, reg))

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_model = model
        best_train_acc_history, best_val_acc_history = solver.train_acc_history, solver.val_acc_history
        
    print(f"hyperparameters lr {lr:.5f}, hidden_size {h}, batch_size {b}, epoch {epoch}, reg {reg:.5f}, train {train_acc:.3f}, val {val_acc:.3f}")


# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# hyperparameters lr 0.04789, hidden_size 80, batch_size 150, epoch 16, reg 0.00001, train 0.634, val 0.541
# hyperparameters lr 0.01377, hidden_size 110, batch_size 50, epoch 18, reg 0.00011, train 0.668, val 0.547
# hyperparameters lr 0.00325, hidden_size 160, batch_size 80, epoch 11, reg 0.00001, train 0.456, val 0.455
# hyperparameters lr 0.03182, hidden_size 100, batch_size 70, epoch 13, reg 0.00076, train 0.656, val 0.528
# hyperparameters lr 0.00234, hidden_size 110, batch_size 70, epoch 15, reg 0.00001, train 0.466, val 0.473
# hyperparameters lr 0.00237, hidden_size 180, batch_size 50, epoch 15, reg 0.00017, train 0.503, val 0.486
# hyperparameters lr 0.00582, hidden_size 170, batch_size 180, epoch 11, reg 0.00003, train 0.410, val 0.442
# hyperparameters lr 0.00200, hidden_size 50, batch_size 150, epoch 17, reg 0.00061, train 0.376, val 0.384
# hyperparameters lr 0.00573, hidden_size 190, batch_size 170, epoch 11, reg 0.00000, train 0.453, val 0.450
# hyperparameters lr 0.03557, hidden_size 80, batch_size 160, epoch 13, reg 0.00015, train 0.626, val 0.523
# hyperparameters lr 0.00771, hidden_size 130, batch_size 80, epoch 12, reg 0.00004, train 0.536, val 0.507
# hyperparameters lr 0.00146, hidden_size 160, batch_size 190, epoch 10, reg 0.00000, train 0.262, val 0.270
# hyperparameters lr 0.00222, hidden_size 80, batch_size 50, epoch 17, reg 0.00033, train 0.503, val 0.481
# hyperparameters lr 0.01031, hidden_size 120, batch_size 70, epoch 19, reg 0.00003, train 0.649, val 0.543
# hyperparameters lr 0.00118, hidden_size 170, batch_size 90, epoch 19, reg 0.00020, train 0.394, val 0.392
# hyperparameters lr 0.05070, hidden_size 180, batch_size 100, epoch 12, reg 0.00012, train 0.638, val 0.518
# hyperparameters lr 0.08727, hidden_size 140, batch_size 110, epoch 17, reg 0.00031, train 0.642, val 0.519
# hyperparameters lr 0.08272, hidden_size 120, batch_size 140, epoch 14, reg 0.00000, train 0.626, val 0.529
# hyperparameters lr 0.00457, hidden_size 180, batch_size 130, epoch 13, reg 0.00000, train 0.459, val 0.462
# hyperparameters lr 0.09170, hidden_size 150, batch_size 160, epoch 18, reg 0.00000, train 0.668, val 0.541
# hyperparameters lr 0.00347, hidden_size 50, batch_size 120, epoch 16, reg 0.00000, train 0.437, val 0.447
# hyperparameters lr 0.00977, hidden_size 150, batch_size 140, epoch 14, reg 0.00032, train 0.548, val 0.490
# hyperparameters lr 0.03699, hidden_size 120, batch_size 50, epoch 13, reg 0.00093, train 0.622, val 0.531
# hyperparameters lr 0.00131, hidden_size 60, batch_size 100, epoch 19, reg 0.00004, train 0.387, val 0.387
# hyperparameters lr 0.00318, hidden_size 160, batch_size 90, epoch 14, reg 0.00038, train 0.475, val 0.468
# hyperparameters lr 0.00354, hidden_size 160, batch_size 140, epoch 11, reg 0.00008, train 0.404, val 0.404
# hyperparameters lr 0.00104, hidden_size 190, batch_size 80, epoch 13, reg 0.00003, train 0.352, val 0.363
# hyperparameters lr 0.00207, hidden_size 130, batch_size 60, epoch 15, reg 0.00003, train 0.462, val 0.460
# hyperparameters lr 0.01074, hidden_size 110, batch_size 100, epoch 13, reg 0.00085, train 0.574, val 0.514
# hyperparameters lr 0.00357, hidden_size 110, batch_size 110, epoch 11, reg 0.00056, train 0.434, val 0.441
# hyperparameters lr 0.00478, hidden_size 50, batch_size 110, epoch 10, reg 0.00000, train 0.465, val 0.450
# hyperparameters lr 0.00157, hidden_size 190, batch_size 160, epoch 17, reg 0.00000, train 0.346, val 0.362
# hyperparameters lr 0.00953, hidden_size 150, batch_size 160, epoch 12, reg 0.00000, train 0.504, val 0.496
# hyperparameters lr 0.02019, hidden_size 70, batch_size 100, epoch 15, reg 0.00032, train 0.605, val 0.536
# hyperparameters lr 0.00150, hidden_size 80, batch_size 160, epoch 12, reg 0.00000, train 0.305, val 0.302
# hyperparameters lr 0.01843, hidden_size 140, batch_size 140, epoch 15, reg 0.00001, train 0.587, val 0.534
# hyperparameters lr 0.00163, hidden_size 190, batch_size 120, epoch 18, reg 0.00000, train 0.393, val 0.397
# hyperparameters lr 0.02031, hidden_size 190, batch_size 60, epoch 18, reg 0.00013, train 0.715, val 0.547
# hyperparameters lr 0.00475, hidden_size 60, batch_size 100, epoch 16, reg 0.00002, train 0.499, val 0.478
# hyperparameters lr 0.08989, hidden_size 140, batch_size 120, epoch 18, reg 0.00003, train 0.668, val 0.520
# hyperparameters lr 0.00159, hidden_size 120, batch_size 50, epoch 18, reg 0.00000, train 0.481, val 0.466
# hyperparameters lr 0.00239, hidden_size 140, batch_size 80, epoch 10, reg 0.00000, train 0.414, val 0.416
# hyperparameters lr 0.00362, hidden_size 130, batch_size 100, epoch 12, reg 0.00001, train 0.454, val 0.449
# hyperparameters lr 0.01172, hidden_size 60, batch_size 50, epoch 15, reg 0.00024, train 0.600, val 0.523
# hyperparameters lr 0.00529, hidden_size 60, batch_size 160, epoch 12, reg 0.00002, train 0.427, val 0.444
# hyperparameters lr 0.00302, hidden_size 170, batch_size 110, epoch 17, reg 0.00020, train 0.459, val 0.454
# hyperparameters lr 0.01035, hidden_size 60, batch_size 120, epoch 18, reg 0.00000, train 0.578, val 0.498
# hyperparameters lr 0.00727, hidden_size 50, batch_size 160, epoch 15, reg 0.00035, train 0.483, val 0.465
# hyperparameters lr 0.00207, hidden_size 50, batch_size 170, epoch 10, reg 0.00000, train 0.315, val 0.294
# hyperparameters lr 0.01543, hidden_size 50, batch_size 170, epoch 19, reg 0.00099, train 0.557, val 0.505
# hyperparameters lr 0.00356, hidden_size 150, batch_size 70, epoch 14, reg 0.00000, train 0.533, val 0.476
# hyperparameters lr 0.02580, hidden_size 100, batch_size 50, epoch 13, reg 0.00002, train 0.633, val 0.535
# hyperparameters lr 0.00130, hidden_size 70, batch_size 90, epoch 19, reg 0.00015, train 0.395, val 0.398
# hyperparameters lr 0.00426, hidden_size 50, batch_size 110, epoch 14, reg 0.00000, train 0.478, val 0.462
# hyperparameters lr 0.00693, hidden_size 180, batch_size 50, epoch 19, reg 0.00000, train 0.646, val 0.536
# hyperparameters lr 0.08238, hidden_size 100, batch_size 140, epoch 13, reg 0.00014, train 0.615, val 0.529
# hyperparameters lr 0.00583, hidden_size 130, batch_size 80, epoch 11, reg 0.00007, train 0.533, val 0.487
# hyperparameters lr 0.01187, hidden_size 100, batch_size 140, epoch 12, reg 0.00003, train 0.531, val 0.497
# hyperparameters lr 0.00359, hidden_size 160, batch_size 70, epoch 19, reg 0.00021, train 0.539, val 0.514
# hyperparameters lr 0.00426, hidden_size 170, batch_size 150, epoch 18, reg 0.00000, train 0.475, val 0.458
# hyperparameters lr 0.00247, hidden_size 150, batch_size 60, epoch 19, reg 0.00021, train 0.504, val 0.475
# hyperparameters lr 0.00577, hidden_size 130, batch_size 80, epoch 15, reg 0.00009, train 0.540, val 0.515
# hyperparameters lr 0.01029, hidden_size 130, batch_size 70, epoch 19, reg 0.00057, train 0.641, val 0.548
# hyperparameters lr 0.00164, hidden_size 50, batch_size 60, epoch 11, reg 0.00004, train 0.385, val 0.400
# hyperparameters lr 0.07565, hidden_size 140, batch_size 50, epoch 18, reg 0.00002, train 0.669, val 0.497
# hyperparameters lr 0.00316, hidden_size 50, batch_size 120, epoch 15, reg 0.00012, train 0.435, val 0.432
# hyperparameters lr 0.03555, hidden_size 110, batch_size 180, epoch 17, reg 0.00001, train 0.626, val 0.535
# hyperparameters lr 0.00485, hidden_size 90, batch_size 90, epoch 14, reg 0.00000, train 0.500, val 0.481
# hyperparameters lr 0.03714, hidden_size 110, batch_size 90, epoch 19, reg 0.00012, train 0.682, val 0.540
# hyperparameters lr 0.00543, hidden_size 90, batch_size 100, epoch 15, reg 0.00010, train 0.509, val 0.485
# hyperparameters lr 0.00413, hidden_size 170, batch_size 50, epoch 17, reg 0.00034, train 0.588, val 0.524
# hyperparameters lr 0.00511, hidden_size 80, batch_size 140, epoch 13, reg 0.00000, train 0.439, val 0.450
# hyperparameters lr 0.00602, hidden_size 60, batch_size 60, epoch 17, reg 0.00001, train 0.541, val 0.497
# hyperparameters lr 0.00278, hidden_size 110, batch_size 150, epoch 14, reg 0.00004, train 0.392, val 0.398
# hyperparameters lr 0.00272, hidden_size 70, batch_size 110, epoch 14, reg 0.00004, train 0.430, val 0.433
# hyperparameters lr 0.00682, hidden_size 60, batch_size 120, epoch 19, reg 0.00001, train 0.535, val 0.495
# hyperparameters lr 0.00273, hidden_size 70, batch_size 180, epoch 10, reg 0.00003, train 0.336, val 0.335
# hyperparameters lr 0.03694, hidden_size 70, batch_size 160, epoch 12, reg 0.00087, train 0.570, val 0.530
# hyperparameters lr 0.01625, hidden_size 120, batch_size 110, epoch 14, reg 0.00002, train 0.603, val 0.537
# hyperparameters lr 0.04273, hidden_size 100, batch_size 110, epoch 12, reg 0.00016, train 0.622, val 0.533
# hyperparameters lr 0.00945, hidden_size 180, batch_size 80, epoch 12, reg 0.00022, train 0.572, val 0.515
# hyperparameters lr 0.00573, hidden_size 150, batch_size 160, epoch 10, reg 0.00000, train 0.427, val 0.438
# hyperparameters lr 0.04804, hidden_size 70, batch_size 120, epoch 17, reg 0.00041, train 0.625, val 0.532
# hyperparameters lr 0.01612, hidden_size 80, batch_size 60, epoch 13, reg 0.00000, train 0.613, val 0.545
# hyperparameters lr 0.01503, hidden_size 90, batch_size 90, epoch 11, reg 0.00002, train 0.579, val 0.541
# hyperparameters lr 0.02092, hidden_size 140, batch_size 150, epoch 10, reg 0.00004, train 0.555, val 0.511
# hyperparameters lr 0.00962, hidden_size 140, batch_size 160, epoch 17, reg 0.00002, train 0.538, val 0.506
# hyperparameters lr 0.00130, hidden_size 100, batch_size 140, epoch 10, reg 0.00006, train 0.283, val 0.276
# hyperparameters lr 0.00174, hidden_size 60, batch_size 130, epoch 19, reg 0.00024, train 0.385, val 0.395
# hyperparameters lr 0.02412, hidden_size 50, batch_size 170, epoch 10, reg 0.00000, train 0.543, val 0.501
# hyperparameters lr 0.03562, hidden_size 160, batch_size 90, epoch 19, reg 0.00009, train 0.692, val 0.549
# hyperparameters lr 0.00369, hidden_size 130, batch_size 110, epoch 13, reg 0.00002, train 0.455, val 0.456
# hyperparameters lr 0.01918, hidden_size 100, batch_size 140, epoch 11, reg 0.00002, train 0.568, val 0.518
# hyperparameters lr 0.00119, hidden_size 100, batch_size 90, epoch 15, reg 0.00033, train 0.355, val 0.372
# hyperparameters lr 0.00122, hidden_size 170, batch_size 70, epoch 12, reg 0.00003, train 0.405, val 0.385
# hyperparameters lr 0.01144, hidden_size 160, batch_size 160, epoch 13, reg 0.00048, train 0.523, val 0.506
# hyperparameters lr 0.03341, hidden_size 160, batch_size 150, epoch 16, reg 0.00003, train 0.662, val 0.549
# hyperparameters lr 0.00310, hidden_size 140, batch_size 120, epoch 14, reg 0.00059, train 0.435, val 0.437
# hyperparameters lr 0.00178, hidden_size 180, batch_size 170, epoch 17, reg 0.00001, train 0.379, val 0.370
# hyperparameters lr 0.00165, hidden_size 90, batch_size 90, epoch 18, reg 0.00065, train 0.428, val 0.432
# hyperparameters lr 0.03805, hidden_size 110, batch_size 100, epoch 15, reg 0.00000, train 0.632, val 0.535
# hyperparameters lr 0.00101, hidden_size 160, batch_size 80, epoch 13, reg 0.00002, train 0.350, val 0.357
# hyperparameters lr 0.02189, hidden_size 150, batch_size 100, epoch 10, reg 0.00001, train 0.578, val 0.521
# hyperparameters lr 0.00859, hidden_size 80, batch_size 180, epoch 13, reg 0.00000, train 0.468, val 0.473
# hyperparameters lr 0.00261, hidden_size 140, batch_size 140, epoch 19, reg 0.00004, train 0.423, val 0.446
# hyperparameters lr 0.00112, hidden_size 170, batch_size 160, epoch 15, reg 0.00000, train 0.310, val 0.304
# hyperparameters lr 0.00931, hidden_size 140, batch_size 170, epoch 10, reg 0.00034, train 0.480, val 0.468
# hyperparameters lr 0.07358, hidden_size 140, batch_size 50, epoch 15, reg 0.00002, train 0.620, val 0.508
# hyperparameters lr 0.00399, hidden_size 60, batch_size 180, epoch 19, reg 0.00007, train 0.464, val 0.447
# hyperparameters lr 0.00912, hidden_size 70, batch_size 90, epoch 12, reg 0.00056, train 0.543, val 0.507
# hyperparameters lr 0.00216, hidden_size 110, batch_size 60, epoch 17, reg 0.00000, train 0.478, val 0.474
# hyperparameters lr 0.03085, hidden_size 90, batch_size 140, epoch 11, reg 0.00000, train 0.578, val 0.539
# hyperparameters lr 0.01598, hidden_size 190, batch_size 190, epoch 17, reg 0.00005, train 0.601, val 0.513
# hyperparameters lr 0.00477, hidden_size 110, batch_size 70, epoch 13, reg 0.00007, train 0.532, val 0.480
# hyperparameters lr 0.06815, hidden_size 190, batch_size 150, epoch 10, reg 0.00000, train 0.621, val 0.539
# hyperparameters lr 0.09153, hidden_size 50, batch_size 180, epoch 11, reg 0.00005, train 0.570, val 0.511
# hyperparameters lr 0.00617, hidden_size 180, batch_size 190, epoch 14, reg 0.00000, train 0.468, val 0.454
# hyperparameters lr 0.03550, hidden_size 190, batch_size 100, epoch 16, reg 0.00004, train 0.711, val 0.543
# hyperparameters lr 0.00443, hidden_size 90, batch_size 180, epoch 14, reg 0.00008, train 0.424, val 0.431
# hyperparameters lr 0.00358, hidden_size 120, batch_size 110, epoch 19, reg 0.00006, train 0.482, val 0.472
# hyperparameters lr 0.00279, hidden_size 130, batch_size 130, epoch 11, reg 0.00054, train 0.377, val 0.387
# hyperparameters lr 0.01045, hidden_size 80, batch_size 130, epoch 19, reg 0.00070, train 0.569, val 0.509
# hyperparameters lr 0.00173, hidden_size 110, batch_size 70, epoch 10, reg 0.00000, train 0.388, val 0.390
# hyperparameters lr 0.00215, hidden_size 60, batch_size 60, epoch 17, reg 0.00044, train 0.479, val 0.467
# hyperparameters lr 0.01089, hidden_size 90, batch_size 150, epoch 11, reg 0.00014, train 0.497, val 0.483
# hyperparameters lr 0.00427, hidden_size 90, batch_size 180, epoch 14, reg 0.00067, train 0.411, val 0.431
# hyperparameters lr 0.00639, hidden_size 120, batch_size 70, epoch 18, reg 0.00053, train 0.592, val 0.535
# hyperparameters lr 0.00210, hidden_size 120, batch_size 180, epoch 11, reg 0.00085, train 0.316, val 0.330
# hyperparameters lr 0.00236, hidden_size 70, batch_size 60, epoch 14, reg 0.00045, train 0.480, val 0.460
# hyperparameters lr 0.04679, hidden_size 120, batch_size 120, epoch 12, reg 0.00022, train 0.637, val 0.540
# hyperparameters lr 0.02755, hidden_size 150, batch_size 90, epoch 16, reg 0.00046, train 0.653, val 0.533
# hyperparameters lr 0.00367, hidden_size 190, batch_size 120, epoch 13, reg 0.00020, train 0.458, val 0.450
# hyperparameters lr 0.01138, hidden_size 140, batch_size 110, epoch 10, reg 0.00001, train 0.551, val 0.506
# hyperparameters lr 0.00212, hidden_size 50, batch_size 160, epoch 10, reg 0.00081, train 0.315, val 0.311
# hyperparameters lr 0.00714, hidden_size 140, batch_size 150, epoch 13, reg 0.00000, train 0.494, val 0.480
# hyperparameters lr 0.00253, hidden_size 130, batch_size 150, epoch 13, reg 0.00000, train 0.375, val 0.383
# hyperparameters lr 0.06776, hidden_size 100, batch_size 130, epoch 10, reg 0.00000, train 0.586, val 0.514
# hyperparameters lr 0.05182, hidden_size 120, batch_size 150, epoch 10, reg 0.00000, train 0.620, val 0.522
# hyperparameters lr 0.00141, hidden_size 170, batch_size 50, epoch 17, reg 0.00002, train 0.457, val 0.470
# hyperparameters lr 0.04560, hidden_size 110, batch_size 110, epoch 18, reg 0.00001, train 0.674, val 0.544
# hyperparameters lr 0.02726, hidden_size 120, batch_size 100, epoch 12, reg 0.00005, train 0.621, val 0.531
# hyperparameters lr 0.00195, hidden_size 100, batch_size 140, epoch 10, reg 0.00000, train 0.345, val 0.330
# hyperparameters lr 0.02615, hidden_size 160, batch_size 180, epoch 18, reg 0.00000, train 0.639, val 0.539
# hyperparameters lr 0.02319, hidden_size 110, batch_size 190, epoch 11, reg 0.00005, train 0.548, val 0.495
# hyperparameters lr 0.00140, hidden_size 150, batch_size 180, epoch 13, reg 0.00000, train 0.293, val 0.299
# hyperparameters lr 0.05080, hidden_size 80, batch_size 110, epoch 16, reg 0.00001, train 0.633, val 0.524
# hyperparameters lr 0.00166, hidden_size 60, batch_size 180, epoch 18, reg 0.00022, train 0.354, val 0.331
# hyperparameters lr 0.00554, hidden_size 130, batch_size 100, epoch 17, reg 0.00001, train 0.540, val 0.508
# hyperparameters lr 0.01838, hidden_size 60, batch_size 180, epoch 12, reg 0.00087, train 0.528, val 0.487
# hyperparameters lr 0.06587, hidden_size 60, batch_size 170, epoch 15, reg 0.00035, train 0.577, val 0.508
# hyperparameters lr 0.00527, hidden_size 120, batch_size 160, epoch 18, reg 0.00001, train 0.481, val 0.474
# hyperparameters lr 0.02461, hidden_size 190, batch_size 150, epoch 16, reg 0.00027, train 0.612, val 0.530
# hyperparameters lr 0.00296, hidden_size 100, batch_size 120, epoch 14, reg 0.00044, train 0.426, val 0.435
# hyperparameters lr 0.03124, hidden_size 130, batch_size 130, epoch 14, reg 0.00001, train 0.632, val 0.531
# hyperparameters lr 0.01730, hidden_size 160, batch_size 140, epoch 17, reg 0.00057, train 0.622, val 0.540
# hyperparameters lr 0.09315, hidden_size 160, batch_size 130, epoch 19, reg 0.00008, train 0.701, val 0.522
# hyperparameters lr 0.07427, hidden_size 130, batch_size 150, epoch 12, reg 0.00000, train 0.661, val 0.530
# hyperparameters lr 0.00901, hidden_size 90, batch_size 170, epoch 19, reg 0.00008, train 0.521, val 0.510
# hyperparameters lr 0.00812, hidden_size 90, batch_size 80, epoch 12, reg 0.00000, train 0.537, val 0.503
# hyperparameters lr 0.00212, hidden_size 60, batch_size 90, epoch 17, reg 0.00000, train 0.455, val 0.446
# hyperparameters lr 0.00219, hidden_size 160, batch_size 50, epoch 13, reg 0.00004, train 0.482, val 0.471
# hyperparameters lr 0.01662, hidden_size 150, batch_size 50, epoch 10, reg 0.00000, train 0.632, val 0.533
# hyperparameters lr 0.00850, hidden_size 60, batch_size 110, epoch 19, reg 0.00000, train 0.550, val 0.512
# hyperparameters lr 0.00310, hidden_size 110, batch_size 190, epoch 13, reg 0.00049, train 0.395, val 0.383
# hyperparameters lr 0.04402, hidden_size 180, batch_size 120, epoch 15, reg 0.00025, train 0.679, val 0.536
# hyperparameters lr 0.00158, hidden_size 190, batch_size 170, epoch 16, reg 0.00000, train 0.356, val 0.341
# hyperparameters lr 0.01082, hidden_size 190, batch_size 90, epoch 13, reg 0.00002, train 0.574, val 0.521
# hyperparameters lr 0.02007, hidden_size 110, batch_size 70, epoch 11, reg 0.00001, train 0.624, val 0.528
# hyperparameters lr 0.07094, hidden_size 130, batch_size 60, epoch 13, reg 0.00013, train 0.620, val 0.499
# hyperparameters lr 0.00701, hidden_size 70, batch_size 60, epoch 18, reg 0.00039, train 0.601, val 0.515
# hyperparameters lr 0.08358, hidden_size 60, batch_size 70, epoch 19, reg 0.00005, train 0.604, val 0.493
# hyperparameters lr 0.00469, hidden_size 120, batch_size 130, epoch 10, reg 0.00090, train 0.418, val 0.436
# hyperparameters lr 0.06356, hidden_size 70, batch_size 80, epoch 17, reg 0.00001, train 0.631, val 0.505
# hyperparameters lr 0.04186, hidden_size 110, batch_size 190, epoch 10, reg 0.00000, train 0.588, val 0.518
# hyperparameters lr 0.00208, hidden_size 100, batch_size 60, epoch 14, reg 0.00006, train 0.480, val 0.467
# hyperparameters lr 0.00303, hidden_size 150, batch_size 60, epoch 19, reg 0.00000, train 0.527, val 0.501
# hyperparameters lr 0.00320, hidden_size 70, batch_size 130, epoch 11, reg 0.00028, train 0.387, val 0.392
# hyperparameters lr 0.02080, hidden_size 90, batch_size 180, epoch 19, reg 0.00098, train 0.605, val 0.518
# hyperparameters lr 0.01987, hidden_size 50, batch_size 110, epoch 17, reg 0.00005, train 0.587, val 0.515
# hyperparameters lr 0.00476, hidden_size 80, batch_size 150, epoch 11, reg 0.00000, train 0.425, val 0.429
# hyperparameters lr 0.00459, hidden_size 170, batch_size 70, epoch 12, reg 0.00014, train 0.518, val 0.485
# hyperparameters lr 0.00311, hidden_size 170, batch_size 150, epoch 15, reg 0.00000, train 0.422, val 0.423
# hyperparameters lr 0.05191, hidden_size 130, batch_size 120, epoch 13, reg 0.00000, train 0.637, val 0.526
# hyperparameters lr 0.08360, hidden_size 50, batch_size 50, epoch 13, reg 0.00001, train 0.554, val 0.466
# hyperparameters lr 0.05177, hidden_size 160, batch_size 100, epoch 10, reg 0.00000, train 0.637, val 0.549
# hyperparameters lr 0.01516, hidden_size 190, batch_size 130, epoch 15, reg 0.00000, train 0.589, val 0.534
# hyperparameters lr 0.08130, hidden_size 150, batch_size 160, epoch 15, reg 0.00000, train 0.653, val 0.537
# hyperparameters lr 0.00439, hidden_size 50, batch_size 180, epoch 14, reg 0.00000, train 0.416, val 0.420
# hyperparameters lr 0.00379, hidden_size 150, batch_size 190, epoch 10, reg 0.00001, train 0.365, val 0.378
# hyperparameters lr 0.00267, hidden_size 90, batch_size 190, epoch 13, reg 0.00000, train 0.363, val 0.364
# hyperparameters lr 0.00818, hidden_size 110, batch_size 130, epoch 18, reg 0.00001, train 0.557, val 0.515
# hyperparameters lr 0.00432, hidden_size 150, batch_size 60, epoch 10, reg 0.00018, train 0.500, val 0.483
# hyperparameters lr 0.02115, hidden_size 140, batch_size 120, epoch 19, reg 0.00046, train 0.646, val 0.542
# hyperparameters lr 0.00929, hidden_size 160, batch_size 80, epoch 17, reg 0.00010, train 0.591, val 0.536
# hyperparameters lr 0.01072, hidden_size 90, batch_size 50, epoch 10, reg 0.00015, train 0.583, val 0.536
# hyperparameters lr 0.00713, hidden_size 140, batch_size 120, epoch 18, reg 0.00000, train 0.534, val 0.517
# hyperparameters lr 0.01398, hidden_size 170, batch_size 180, epoch 19, reg 0.00000, train 0.588, val 0.523
# hyperparameters lr 0.06645, hidden_size 80, batch_size 160, epoch 16, reg 0.00049, train 0.630, val 0.518
# hyperparameters lr 0.09035, hidden_size 130, batch_size 80, epoch 19, reg 0.00001, train 0.656, val 0.523
# hyperparameters lr 0.02776, hidden_size 120, batch_size 140, epoch 10, reg 0.00023, train 0.557, val 0.525

# %%
for val_acc, train_acc, lr, h, b, epoch, reg in sorted(top10):
    print(f"top10 params: lr {lr:.5f}, hidden_size {h}, batch_size {b}, epoch {epoch}, reg {reg:.6f}, train {train_acc:.3f}, val {val_acc:.3f}")
# Out:
# top10 params: lr 0.01031, hidden_size 120, batch_size 70, epoch 19, reg 0.000032, train 0.649, val 0.543
# top10 params: lr 0.03550, hidden_size 190, batch_size 100, epoch 16, reg 0.000038, train 0.711, val 0.543
# top10 params: lr 0.04560, hidden_size 110, batch_size 110, epoch 18, reg 0.000005, train 0.674, val 0.544
# top10 params: lr 0.01612, hidden_size 80, batch_size 60, epoch 13, reg 0.000004, train 0.613, val 0.545
# top10 params: lr 0.01377, hidden_size 110, batch_size 50, epoch 18, reg 0.000105, train 0.668, val 0.547
# top10 params: lr 0.02031, hidden_size 190, batch_size 60, epoch 18, reg 0.000127, train 0.715, val 0.547
# top10 params: lr 0.01029, hidden_size 130, batch_size 70, epoch 19, reg 0.000574, train 0.641, val 0.548
# top10 params: lr 0.05177, hidden_size 160, batch_size 100, epoch 10, reg 0.000002, train 0.637, val 0.549
# top10 params: lr 0.03341, hidden_size 160, batch_size 150, epoch 16, reg 0.000031, train 0.662, val 0.549
# top10 params: lr 0.03562, hidden_size 160, batch_size 90, epoch 19, reg 0.000090, train 0.692, val 0.549

# %%
plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.plot(best_train_acc_history, '-o', label='train')
plt.plot(best_val_acc_history, '-o', label='val')
plt.plot([0.5] * len(best_train_acc_history), 'k--')
plt.plot([0.6] * len(best_train_acc_history), 'k--')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %%
show_net_weights(model)

# %% [markdown]
# # Test your model!
# Run your best model on the validation and test sets. You should achieve above 48% accuracy on the validation set and the test set.

# %%
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
# Out:
# Validation set accuracy:  0.549

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Test set accuracy:  0.525

# %% [markdown]
# ## Inline Question 2:
#
# Now that you have trained a Neural Network classifier, you may find that your testing accuracy is much lower than the training accuracy. In what ways can we decrease this gap? Select all that apply.
#
# 1. Train on a larger dataset.
# 2. Add more hidden units.
# 3. Increase the regularization strength.
# 4. None of the above.
#
# $\color{blue}{\textit Your Answer:}$
#
# $\color{blue}{\textit Your Explanation:}$
